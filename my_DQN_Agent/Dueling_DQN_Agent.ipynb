# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch

import imageio
import os
import random

import utils.memory as mem   
from utils.feedforward import Feedforward
import utils.help_classes as hc
import utils.stats_functions as sf

# %%
SEED_TRAIN_1 = 7489
SEED_TRAIN_2 = 1312
SEEDS_TEST = [291, 292, 293, 294, 295]

# %% [markdown]
# ## Dueling-DQN Algorithm

# %% [markdown]
# ### Q-Function

# %%
class QFunction(Feedforward):

    def __init__(self, state_dim, action_dim, hidden_sizes=[128,128], learning_rate = 0.0002):

        super().__init__(input_size=state_dim, hidden_sizes=hidden_sizes, output_size=action_dim)

        self.optimizer=torch.optim.Adam(self.parameters(), 
                                        lr=learning_rate, 
                                        eps=0.000001)
        self.loss = torch.nn.SmoothL1Loss() # MSELoss()

    def fit(self, states, actions, targets):

        self.train() # put model in training mode
        self.optimizer.zero_grad()

        # Forward pass
        acts = torch.from_numpy(actions)
        pred = self.Q_value(torch.from_numpy(states).float(), acts)

        # Compute Loss
        loss = self.loss(pred, torch.from_numpy(targets).float())
        
        # Backward pass
        loss.backward()
        self.optimizer.step()
        return loss.item()

    def Q_value(self, states, actions):
        return self.forward(states).gather(1, actions[:,None])        
    
    def maxQ(self, states):
        return np.max(self.predict(states), axis=-1, keepdims=True)
        
    def greedyAction(self, states):
        return np.argmax(self.predict(states), axis=-1)
    
    def save(self, env_name, name):
            os.makedirs(f"{env_name}/weights", exist_ok=True)
            torch.save(self.state_dict(), f"{env_name}/weights/{name}.pth")
            print(f"Network saved at {env_name}/weights/{name}.pth")

    def load(self, env_name, name = "training_finished"):
            self.load_state_dict(torch.load(f"{env_name}/weights/{name}.pth"))
            print(f"Network loaded from {env_name}/weights/{name}.pth")

# %%
class DQN_Agent(object):

    def __init__(self, state_space, action_space, **userconfig):
        
        if not isinstance(state_space, spaces.box.Box):
            raise hc.UnsupportedSpace("Observation space {} incompatible with {}. (Require: Box)".format(state_space, self))
        if not isinstance(action_space, spaces.discrete.Discrete):
            raise hc.UnsupportedSpace("Action space {} incompatible with {}. (Reqire Discrete.)".format(action_space, self))
        
        self._state_space = state_space
        self._action_space = action_space
        self._action_n = action_space.n

        self.train_iter = 0

        self._config = {
            "eps": 0.05,                       
            "discount": 0.95,
            "buffer_size": int(1e5),
            "batch_size": 128,
            "learning_rate": 0.0002,
            "update_target_every": 20,
            "use_target_net": True,
            "use_eps_decay": False,
            "eps_decay_mode": "exponential",
            "eps_min": 0.01,
            "eps_decay": 0.995,
            "seed": random.random()
        }

        self._config.update(userconfig)
             
        self._eps = self._config["eps"]
        
        self.buffer = mem.Memory(max_size=self._config["buffer_size"])
                
        # Q Network
        self.Q = QFunction(state_dim=self._state_space.shape[0], 
                           action_dim=self._action_n,
                           learning_rate = self._config["learning_rate"])
        
        # Q Target
        self.Q_target = QFunction(state_dim=self._state_space.shape[0], 
                                  action_dim=self._action_n,
                                  learning_rate = 0)    # We do not want to train the Target Function, only copy the weights of the Q Network
        self._update_target_net()

    def _update_target_net(self):        
        self.Q_target.load_state_dict(self.Q.state_dict())
    
    def perform_greedy_action(self, state, eps = None):

        if eps is None:
            eps = self._eps

        if np.random.random() > eps:
            action = self.Q.greedyAction(state)
        else: 
            action = self._action_space.sample()        
        return action

    def _perform_epsilon_decay(self):

        if self._config["eps_decay_mode"] == "linear":
            self._eps = max(self._config["eps_min"], self._eps - self._config["eps_decay"])
        elif self._config["eps_decay_mode"] == "exponential":
            self._eps = max(self._config["eps_min"], self._eps * self._config["eps_decay"])
        else:
            raise ValueError("Error: Epsilon decay mode must be \"linear\" or \"exponential\".")

    def train(self, iter_fit=32):

        losses = []
        self.train_iter+=1
                     
        for i in range(iter_fit):

            # Sample from the replay buffer
            random.seed(self._config["seed"])
            data = self.buffer.sample(batch=self._config["batch_size"])
            s = np.stack(data[:,0]) # Current state (s_t)
            a = np.stack(data[:,1]) # Action taken (a_t)
            rew = np.stack(data[:,2])[:,None] # Reward received (r)
            s_prime = np.stack(data[:,3]) # Next state (s_t+1)
            done = np.stack(data[:,4])[:,None] # Done flag (1 if terminal, else 0)

            
            if self._config["use_target_net"]:
                v_prime = self.Q_target.maxQ(s_prime)
            else:
                v_prime = self.Q.maxQ(s_prime)

            # target                                              
            td_target = rew + self._config["discount"] * (1.0 - done) * v_prime
            
            # optimize the lsq objective
            fit_loss = self.Q.fit(s, a, td_target)
            
            losses.append(fit_loss)

        if self._config["use_target_net"] and self.train_iter % self._config["update_target_every"] == 0:
            self._update_target_net()
                
        return losses

# %% [markdown]
# ## Training the Agent: SEED 1

# %%
seed = SEED_TRAIN_1

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# Ensure deterministic behavior in CUDA if available
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

#env_name = "CartPole-v1"
env_name = "DuelingDQN_CartPole_Check_if_works"
env = gym.make("CartPole-v1", render_mode="rgb_array")
if isinstance(env.action_space, spaces.Box):
    env = hc.DiscreteActionWrapper(env,5)

# Initialize the agent with the correct state/action space
state_space = env.observation_space
action_space = env.action_space
agent = DQN_Agent(state_space, action_space, use_eps_decay = True)

stats = []
losses = []

max_episodes = 500
max_steps = 1000
train_iterations = 32  # Number of training steps per episode

for episode in range(max_episodes):

    state = env.reset(seed = seed)
    state = state[0] if isinstance(state, tuple) else state  # Handle Gymnasium compatibility
    total_reward = 0
    
    for t in range(max_steps):
        done = False
        action = agent.perform_greedy_action(state)
        next_state, reward, done, truncated, _ = env.step(action)
        
        total_reward += reward

        agent.buffer.add_transition((state, action, reward, next_state, done))      # Store transition in the agent"s memory and then train

        state = next_state

        if done: break
        
    losses.extend(agent.train(train_iterations))
    stats.append([episode, total_reward, t + 1])
    
    if agent._config["use_eps_decay"] and episode > int(0.5 * max_episodes):
        agent._perform_epsilon_decay()

    print(f"Episode {episode+1}/{max_episodes}, Total Reward: {total_reward}")
        
    if ((episode) % int(max_episodes/10) == 0) and episode > 0:
        agent.Q.save(env_name, name = f"episode_{episode}")

agent.Q.save(env_name, name = "training_finished")
sf.save_stats(env_name, stats, losses)
# Out:
# Episode 1/500, Total Reward: 10.0
# Episode 2/500, Total Reward: 10.0
# Episode 3/500, Total Reward: 11.0
# Episode 4/500, Total Reward: 10.0
# Episode 5/500, Total Reward: 11.0
# Episode 6/500, Total Reward: 11.0
# Episode 7/500, Total Reward: 11.0
# Episode 8/500, Total Reward: 11.0
# Episode 9/500, Total Reward: 11.0
# Episode 10/500, Total Reward: 11.0
# Episode 11/500, Total Reward: 11.0
# Episode 12/500, Total Reward: 11.0
# Episode 13/500, Total Reward: 11.0
# Episode 14/500, Total Reward: 11.0
# Episode 15/500, Total Reward: 13.0
# Episode 16/500, Total Reward: 11.0
# Episode 17/500, Total Reward: 11.0
# Episode 18/500, Total Reward: 12.0
# Episode 19/500, Total Reward: 12.0
# Episode 20/500, Total Reward: 12.0
# Episode 21/500, Total Reward: 12.0
# Episode 22/500, Total Reward: 13.0
# Episode 23/500, Total Reward: 13.0
# Episode 24/500, Total Reward: 13.0
# Episode 25/500, Total Reward: 14.0
# Episode 26/500, Total Reward: 16.0
# Episode 27/500, Total Reward: 16.0
# Episode 28/500, Total Reward: 16.0
# Episode 29/500, Total Reward: 16.0
# Episode 30/500, Total Reward: 18.0
# Episode 31/500, Total Reward: 18.0
# Episode 32/500, Total Reward: 19.0
# Episode 33/500, Total Reward: 26.0
# Episode 34/500, Total Reward: 24.0
# Episode 35/500, Total Reward: 29.0
# Episode 36/500, Total Reward: 37.0
# Episode 37/500, Total Reward: 35.0
# Episode 38/500, Total Reward: 32.0
# Episode 39/500, Total Reward: 34.0
# Episode 40/500, Total Reward: 30.0
# Episode 41/500, Total Reward: 22.0
# Episode 42/500, Total Reward: 19.0
# Episode 43/500, Total Reward: 18.0
# Episode 44/500, Total Reward: 20.0
# Episode 45/500, Total Reward: 22.0
# Episode 46/500, Total Reward: 24.0
# Episode 47/500, Total Reward: 29.0
# Episode 48/500, Total Reward: 29.0
# Episode 49/500, Total Reward: 35.0
# Episode 50/500, Total Reward: 27.0
# Episode 51/500, Total Reward: 27.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_50.pth
# Episode 52/500, Total Reward: 27.0
# Episode 53/500, Total Reward: 26.0
# Episode 54/500, Total Reward: 23.0
# Episode 55/500, Total Reward: 27.0
# Episode 56/500, Total Reward: 28.0
# Episode 57/500, Total Reward: 20.0
# Episode 58/500, Total Reward: 19.0
# Episode 59/500, Total Reward: 26.0
# Episode 60/500, Total Reward: 23.0
# Episode 61/500, Total Reward: 27.0
# Episode 62/500, Total Reward: 29.0
# Episode 63/500, Total Reward: 43.0
# Episode 64/500, Total Reward: 26.0
# Episode 65/500, Total Reward: 25.0
# Episode 66/500, Total Reward: 62.0
# Episode 67/500, Total Reward: 29.0
# Episode 68/500, Total Reward: 27.0
# Episode 69/500, Total Reward: 44.0
# Episode 70/500, Total Reward: 28.0
# Episode 71/500, Total Reward: 24.0
# Episode 72/500, Total Reward: 60.0
# Episode 73/500, Total Reward: 37.0
# Episode 74/500, Total Reward: 24.0
# Episode 75/500, Total Reward: 23.0
# Episode 76/500, Total Reward: 24.0
# Episode 77/500, Total Reward: 28.0
# Episode 78/500, Total Reward: 32.0
# Episode 79/500, Total Reward: 24.0
# Episode 80/500, Total Reward: 28.0
# Episode 81/500, Total Reward: 28.0
# Episode 82/500, Total Reward: 26.0
# Episode 83/500, Total Reward: 26.0
# Episode 84/500, Total Reward: 28.0
# Episode 85/500, Total Reward: 30.0
# Episode 86/500, Total Reward: 27.0
# Episode 87/500, Total Reward: 24.0
# Episode 88/500, Total Reward: 30.0
# Episode 89/500, Total Reward: 24.0
# Episode 90/500, Total Reward: 27.0
# Episode 91/500, Total Reward: 30.0
# Episode 92/500, Total Reward: 30.0
# Episode 93/500, Total Reward: 31.0
# Episode 94/500, Total Reward: 32.0
# Episode 95/500, Total Reward: 29.0
# Episode 96/500, Total Reward: 25.0
# Episode 97/500, Total Reward: 28.0
# Episode 98/500, Total Reward: 24.0
# Episode 99/500, Total Reward: 32.0
# Episode 100/500, Total Reward: 26.0
# Episode 101/500, Total Reward: 29.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_100.pth
# Episode 102/500, Total Reward: 39.0
# Episode 103/500, Total Reward: 35.0
# Episode 104/500, Total Reward: 35.0
# Episode 105/500, Total Reward: 35.0
# Episode 106/500, Total Reward: 34.0
# Episode 107/500, Total Reward: 34.0
# Episode 108/500, Total Reward: 35.0
# Episode 109/500, Total Reward: 36.0
# Episode 110/500, Total Reward: 37.0
# Episode 111/500, Total Reward: 40.0
# Episode 112/500, Total Reward: 35.0
# Episode 113/500, Total Reward: 41.0
# Episode 114/500, Total Reward: 36.0
# Episode 115/500, Total Reward: 36.0
# Episode 116/500, Total Reward: 37.0
# Episode 117/500, Total Reward: 40.0
# Episode 118/500, Total Reward: 42.0
# Episode 119/500, Total Reward: 40.0
# Episode 120/500, Total Reward: 44.0
# Episode 121/500, Total Reward: 43.0
# Episode 122/500, Total Reward: 59.0
# Episode 123/500, Total Reward: 68.0
# Episode 124/500, Total Reward: 78.0
# Episode 125/500, Total Reward: 85.0
# Episode 126/500, Total Reward: 86.0
# Episode 127/500, Total Reward: 101.0
# Episode 128/500, Total Reward: 144.0
# Episode 129/500, Total Reward: 144.0
# Episode 130/500, Total Reward: 147.0
# Episode 131/500, Total Reward: 144.0
# Episode 132/500, Total Reward: 149.0
# Episode 133/500, Total Reward: 146.0
# Episode 134/500, Total Reward: 142.0
# Episode 135/500, Total Reward: 142.0
# Episode 136/500, Total Reward: 147.0
# Episode 137/500, Total Reward: 144.0
# Episode 138/500, Total Reward: 144.0
# Episode 139/500, Total Reward: 141.0
# Episode 140/500, Total Reward: 150.0
# Episode 141/500, Total Reward: 147.0
# Episode 142/500, Total Reward: 155.0
# Episode 143/500, Total Reward: 149.0
# Episode 144/500, Total Reward: 141.0
# Episode 145/500, Total Reward: 131.0
# Episode 146/500, Total Reward: 137.0
# Episode 147/500, Total Reward: 140.0
# Episode 148/500, Total Reward: 141.0
# Episode 149/500, Total Reward: 133.0
# Episode 150/500, Total Reward: 136.0
# Episode 151/500, Total Reward: 138.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_150.pth
# Episode 152/500, Total Reward: 132.0
# Episode 153/500, Total Reward: 137.0
# Episode 154/500, Total Reward: 132.0
# Episode 155/500, Total Reward: 139.0
# Episode 156/500, Total Reward: 125.0
# Episode 157/500, Total Reward: 130.0
# Episode 158/500, Total Reward: 134.0
# Episode 159/500, Total Reward: 130.0
# Episode 160/500, Total Reward: 127.0
# Episode 161/500, Total Reward: 127.0
# Episode 162/500, Total Reward: 153.0
# Episode 163/500, Total Reward: 149.0
# Episode 164/500, Total Reward: 143.0
# Episode 165/500, Total Reward: 141.0
# Episode 166/500, Total Reward: 143.0
# Episode 167/500, Total Reward: 143.0
# Episode 168/500, Total Reward: 149.0
# Episode 169/500, Total Reward: 143.0
# Episode 170/500, Total Reward: 149.0
# Episode 171/500, Total Reward: 146.0
# Episode 172/500, Total Reward: 137.0
# Episode 173/500, Total Reward: 143.0
# Episode 174/500, Total Reward: 146.0
# Episode 175/500, Total Reward: 137.0
# Episode 176/500, Total Reward: 139.0
# Episode 177/500, Total Reward: 139.0
# Episode 178/500, Total Reward: 145.0
# Episode 179/500, Total Reward: 143.0
# Episode 180/500, Total Reward: 142.0
# Episode 181/500, Total Reward: 144.0
# Episode 182/500, Total Reward: 141.0
# Episode 183/500, Total Reward: 143.0
# Episode 184/500, Total Reward: 142.0
# Episode 185/500, Total Reward: 142.0
# Episode 186/500, Total Reward: 141.0
# Episode 187/500, Total Reward: 142.0
# Episode 188/500, Total Reward: 145.0
# Episode 189/500, Total Reward: 147.0
# Episode 190/500, Total Reward: 137.0
# Episode 191/500, Total Reward: 141.0
# Episode 192/500, Total Reward: 139.0
# Episode 193/500, Total Reward: 145.0
# Episode 194/500, Total Reward: 138.0
# Episode 195/500, Total Reward: 137.0
# Episode 196/500, Total Reward: 141.0
# Episode 197/500, Total Reward: 141.0
# Episode 198/500, Total Reward: 137.0
# Episode 199/500, Total Reward: 142.0
# Episode 200/500, Total Reward: 142.0
# Episode 201/500, Total Reward: 142.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_200.pth
# Episode 202/500, Total Reward: 147.0
# Episode 203/500, Total Reward: 147.0
# Episode 204/500, Total Reward: 151.0
# Episode 205/500, Total Reward: 147.0
# Episode 206/500, Total Reward: 143.0
# Episode 207/500, Total Reward: 151.0
# Episode 208/500, Total Reward: 148.0
# Episode 209/500, Total Reward: 143.0
# Episode 210/500, Total Reward: 147.0
# Episode 211/500, Total Reward: 141.0
# Episode 212/500, Total Reward: 151.0
# Episode 213/500, Total Reward: 144.0
# Episode 214/500, Total Reward: 143.0
# Episode 215/500, Total Reward: 143.0
# Episode 216/500, Total Reward: 143.0
# Episode 217/500, Total Reward: 145.0
# Episode 218/500, Total Reward: 145.0
# Episode 219/500, Total Reward: 144.0
# Episode 220/500, Total Reward: 144.0
# Episode 221/500, Total Reward: 144.0
# Episode 222/500, Total Reward: 137.0
# Episode 223/500, Total Reward: 141.0
# Episode 224/500, Total Reward: 144.0
# Episode 225/500, Total Reward: 146.0
# Episode 226/500, Total Reward: 143.0
# Episode 227/500, Total Reward: 147.0
# Episode 228/500, Total Reward: 142.0
# Episode 229/500, Total Reward: 140.0
# Episode 230/500, Total Reward: 143.0
# Episode 231/500, Total Reward: 144.0
# Episode 232/500, Total Reward: 142.0
# Episode 233/500, Total Reward: 144.0
# Episode 234/500, Total Reward: 140.0
# Episode 235/500, Total Reward: 144.0
# Episode 236/500, Total Reward: 140.0
# Episode 237/500, Total Reward: 146.0
# Episode 238/500, Total Reward: 142.0
# Episode 239/500, Total Reward: 145.0
# Episode 240/500, Total Reward: 142.0
# Episode 241/500, Total Reward: 138.0
# Episode 242/500, Total Reward: 142.0
# Episode 243/500, Total Reward: 148.0
# Episode 244/500, Total Reward: 151.0
# Episode 245/500, Total Reward: 146.0
# Episode 246/500, Total Reward: 154.0
# Episode 247/500, Total Reward: 151.0
# Episode 248/500, Total Reward: 149.0
# Episode 249/500, Total Reward: 144.0
# Episode 250/500, Total Reward: 147.0
# Episode 251/500, Total Reward: 152.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_250.pth
# Episode 252/500, Total Reward: 145.0
# Episode 253/500, Total Reward: 147.0
# Episode 254/500, Total Reward: 155.0
# Episode 255/500, Total Reward: 147.0
# Episode 256/500, Total Reward: 148.0
# Episode 257/500, Total Reward: 148.0
# Episode 258/500, Total Reward: 143.0
# Episode 259/500, Total Reward: 148.0
# Episode 260/500, Total Reward: 149.0
# Episode 261/500, Total Reward: 157.0
# Episode 262/500, Total Reward: 143.0
# Episode 263/500, Total Reward: 142.0
# Episode 264/500, Total Reward: 145.0
# Episode 265/500, Total Reward: 144.0
# Episode 266/500, Total Reward: 142.0
# Episode 267/500, Total Reward: 149.0
# Episode 268/500, Total Reward: 145.0
# Episode 269/500, Total Reward: 145.0
# Episode 270/500, Total Reward: 144.0
# Episode 271/500, Total Reward: 140.0
# Episode 272/500, Total Reward: 142.0
# Episode 273/500, Total Reward: 139.0
# Episode 274/500, Total Reward: 140.0
# Episode 275/500, Total Reward: 139.0
# Episode 276/500, Total Reward: 145.0
# Episode 277/500, Total Reward: 139.0
# Episode 278/500, Total Reward: 139.0
# Episode 279/500, Total Reward: 145.0
# Episode 280/500, Total Reward: 146.0
# Episode 281/500, Total Reward: 136.0
# Episode 282/500, Total Reward: 143.0
# Episode 283/500, Total Reward: 153.0
# Episode 284/500, Total Reward: 164.0
# Episode 285/500, Total Reward: 148.0
# Episode 286/500, Total Reward: 156.0
# Episode 287/500, Total Reward: 169.0
# Episode 288/500, Total Reward: 155.0
# Episode 289/500, Total Reward: 152.0
# Episode 290/500, Total Reward: 149.0
# Episode 291/500, Total Reward: 149.0
# Episode 292/500, Total Reward: 160.0
# Episode 293/500, Total Reward: 152.0
# Episode 294/500, Total Reward: 153.0
# Episode 295/500, Total Reward: 153.0
# Episode 296/500, Total Reward: 145.0
# Episode 297/500, Total Reward: 152.0
# Episode 298/500, Total Reward: 148.0
# Episode 299/500, Total Reward: 159.0
# Episode 300/500, Total Reward: 148.0
# Episode 301/500, Total Reward: 149.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_300.pth
# Episode 302/500, Total Reward: 136.0
# Episode 303/500, Total Reward: 153.0
# Episode 304/500, Total Reward: 153.0
# Episode 305/500, Total Reward: 150.0
# Episode 306/500, Total Reward: 149.0
# Episode 307/500, Total Reward: 150.0
# Episode 308/500, Total Reward: 146.0
# Episode 309/500, Total Reward: 146.0
# Episode 310/500, Total Reward: 144.0
# Episode 311/500, Total Reward: 146.0
# Episode 312/500, Total Reward: 140.0
# Episode 313/500, Total Reward: 137.0
# Episode 314/500, Total Reward: 143.0
# Episode 315/500, Total Reward: 138.0
# Episode 316/500, Total Reward: 134.0
# Episode 317/500, Total Reward: 138.0
# Episode 318/500, Total Reward: 129.0
# Episode 319/500, Total Reward: 132.0
# Episode 320/500, Total Reward: 126.0
# Episode 321/500, Total Reward: 129.0
# Episode 322/500, Total Reward: 137.0
# Episode 323/500, Total Reward: 140.0
# Episode 324/500, Total Reward: 140.0
# Episode 325/500, Total Reward: 143.0
# Episode 326/500, Total Reward: 148.0
# Episode 327/500, Total Reward: 146.0
# Episode 328/500, Total Reward: 136.0
# Episode 329/500, Total Reward: 135.0
# Episode 330/500, Total Reward: 133.0
# Episode 331/500, Total Reward: 138.0
# Episode 332/500, Total Reward: 132.0
# Episode 333/500, Total Reward: 139.0
# Episode 334/500, Total Reward: 135.0
# Episode 335/500, Total Reward: 130.0
# Episode 336/500, Total Reward: 134.0
# Episode 337/500, Total Reward: 127.0
# Episode 338/500, Total Reward: 132.0
# Episode 339/500, Total Reward: 131.0
# Episode 340/500, Total Reward: 130.0
# Episode 341/500, Total Reward: 134.0
# Episode 342/500, Total Reward: 136.0
# Episode 343/500, Total Reward: 135.0
# Episode 344/500, Total Reward: 139.0
# Episode 345/500, Total Reward: 133.0
# Episode 346/500, Total Reward: 131.0
# Episode 347/500, Total Reward: 129.0
# Episode 348/500, Total Reward: 130.0
# Episode 349/500, Total Reward: 129.0
# Episode 350/500, Total Reward: 139.0
# Episode 351/500, Total Reward: 132.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_350.pth
# Episode 352/500, Total Reward: 129.0
# Episode 353/500, Total Reward: 131.0
# Episode 354/500, Total Reward: 131.0
# Episode 355/500, Total Reward: 128.0
# Episode 356/500, Total Reward: 122.0
# Episode 357/500, Total Reward: 127.0
# Episode 358/500, Total Reward: 130.0
# Episode 359/500, Total Reward: 127.0
# Episode 360/500, Total Reward: 125.0
# Episode 361/500, Total Reward: 127.0
# Episode 362/500, Total Reward: 131.0
# Episode 363/500, Total Reward: 144.0
# Episode 364/500, Total Reward: 136.0
# Episode 365/500, Total Reward: 136.0
# Episode 366/500, Total Reward: 137.0
# Episode 367/500, Total Reward: 136.0
# Episode 368/500, Total Reward: 133.0
# Episode 369/500, Total Reward: 139.0
# Episode 370/500, Total Reward: 135.0
# Episode 371/500, Total Reward: 139.0
# Episode 372/500, Total Reward: 141.0
# Episode 373/500, Total Reward: 134.0
# Episode 374/500, Total Reward: 139.0
# Episode 375/500, Total Reward: 137.0
# Episode 376/500, Total Reward: 135.0
# Episode 377/500, Total Reward: 141.0
# Episode 378/500, Total Reward: 136.0
# Episode 379/500, Total Reward: 136.0
# Episode 380/500, Total Reward: 135.0
# Episode 381/500, Total Reward: 137.0
# Episode 382/500, Total Reward: 130.0
# Episode 383/500, Total Reward: 139.0
# Episode 384/500, Total Reward: 136.0
# Episode 385/500, Total Reward: 138.0
# Episode 386/500, Total Reward: 143.0
# Episode 387/500, Total Reward: 137.0
# Episode 388/500, Total Reward: 143.0
# Episode 389/500, Total Reward: 143.0
# Episode 390/500, Total Reward: 134.0
# Episode 391/500, Total Reward: 139.0
# Episode 392/500, Total Reward: 146.0
# Episode 393/500, Total Reward: 138.0
# Episode 394/500, Total Reward: 137.0
# Episode 395/500, Total Reward: 140.0
# Episode 396/500, Total Reward: 133.0
# Episode 397/500, Total Reward: 133.0
# Episode 398/500, Total Reward: 129.0
# Episode 399/500, Total Reward: 137.0
# Episode 400/500, Total Reward: 135.0
# Episode 401/500, Total Reward: 139.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_400.pth
# Episode 402/500, Total Reward: 135.0
# Episode 403/500, Total Reward: 141.0
# Episode 404/500, Total Reward: 138.0
# Episode 405/500, Total Reward: 134.0
# Episode 406/500, Total Reward: 133.0
# Episode 407/500, Total Reward: 138.0
# Episode 408/500, Total Reward: 135.0
# Episode 409/500, Total Reward: 134.0
# Episode 410/500, Total Reward: 139.0
# Episode 411/500, Total Reward: 137.0
# Episode 412/500, Total Reward: 134.0
# Episode 413/500, Total Reward: 129.0
# Episode 414/500, Total Reward: 133.0
# Episode 415/500, Total Reward: 133.0
# Episode 416/500, Total Reward: 137.0
# Episode 417/500, Total Reward: 141.0
# Episode 418/500, Total Reward: 133.0
# Episode 419/500, Total Reward: 134.0
# Episode 420/500, Total Reward: 139.0
# Episode 421/500, Total Reward: 133.0
# Episode 422/500, Total Reward: 134.0
# Episode 423/500, Total Reward: 157.0
# Episode 424/500, Total Reward: 142.0
# Episode 425/500, Total Reward: 140.0
# Episode 426/500, Total Reward: 139.0
# Episode 427/500, Total Reward: 137.0
# Episode 428/500, Total Reward: 141.0
# Episode 429/500, Total Reward: 139.0
# Episode 430/500, Total Reward: 142.0
# Episode 431/500, Total Reward: 146.0
# Episode 432/500, Total Reward: 145.0
# Episode 433/500, Total Reward: 147.0
# Episode 434/500, Total Reward: 142.0
# Episode 435/500, Total Reward: 146.0
# Episode 436/500, Total Reward: 147.0
# Episode 437/500, Total Reward: 138.0
# Episode 438/500, Total Reward: 154.0
# Episode 439/500, Total Reward: 142.0
# Episode 440/500, Total Reward: 146.0
# Episode 441/500, Total Reward: 143.0
# Episode 442/500, Total Reward: 136.0
# Episode 443/500, Total Reward: 136.0
# Episode 444/500, Total Reward: 147.0
# Episode 445/500, Total Reward: 136.0
# Episode 446/500, Total Reward: 137.0
# Episode 447/500, Total Reward: 138.0
# Episode 448/500, Total Reward: 148.0
# Episode 449/500, Total Reward: 140.0
# Episode 450/500, Total Reward: 144.0
# Episode 451/500, Total Reward: 142.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/episode_450.pth
# Episode 452/500, Total Reward: 142.0
# Episode 453/500, Total Reward: 143.0
# Episode 454/500, Total Reward: 136.0
# Episode 455/500, Total Reward: 150.0
# Episode 456/500, Total Reward: 140.0
# Episode 457/500, Total Reward: 142.0
# Episode 458/500, Total Reward: 142.0
# Episode 459/500, Total Reward: 143.0
# Episode 460/500, Total Reward: 138.0
# Episode 461/500, Total Reward: 143.0
# Episode 462/500, Total Reward: 138.0
# Episode 463/500, Total Reward: 135.0
# Episode 464/500, Total Reward: 144.0
# Episode 465/500, Total Reward: 143.0
# Episode 466/500, Total Reward: 150.0
# Episode 467/500, Total Reward: 140.0
# Episode 468/500, Total Reward: 140.0
# Episode 469/500, Total Reward: 145.0
# Episode 470/500, Total Reward: 155.0
# Episode 471/500, Total Reward: 133.0
# Episode 472/500, Total Reward: 146.0
# Episode 473/500, Total Reward: 136.0
# Episode 474/500, Total Reward: 141.0
# Episode 475/500, Total Reward: 140.0
# Episode 476/500, Total Reward: 138.0
# Episode 477/500, Total Reward: 139.0
# Episode 478/500, Total Reward: 157.0
# Episode 479/500, Total Reward: 139.0
# Episode 480/500, Total Reward: 139.0
# Episode 481/500, Total Reward: 138.0
# Episode 482/500, Total Reward: 140.0
# Episode 483/500, Total Reward: 146.0
# Episode 484/500, Total Reward: 143.0
# Episode 485/500, Total Reward: 149.0
# Episode 486/500, Total Reward: 144.0
# Episode 487/500, Total Reward: 148.0
# Episode 488/500, Total Reward: 136.0
# Episode 489/500, Total Reward: 145.0
# Episode 490/500, Total Reward: 141.0
# Episode 491/500, Total Reward: 150.0
# Episode 492/500, Total Reward: 142.0
# Episode 493/500, Total Reward: 149.0
# Episode 494/500, Total Reward: 144.0
# Episode 495/500, Total Reward: 151.0
# Episode 496/500, Total Reward: 139.0
# Episode 497/500, Total Reward: 148.0
# Episode 498/500, Total Reward: 145.0
# Episode 499/500, Total Reward: 142.0
# Episode 500/500, Total Reward: 151.0
# Network saved at DuelingDQN_CartPole_Check_if_works/weights/training_finished.pth

# %%
sf.plot_returns(stats, env_name)
# Out:
# Plot saved at DuelingDQN_CartPole_Check_if_works/stats/plots/returns_plot.png

# %%
sf.plot_losses(losses, env_name)
# Out:
# Plot saved at DuelingDQN_CartPole_Check_if_works/stats/plots/losses_plot.png

# %% [markdown]
# ## Testing the Agent

# %%
test_episodes = len(SEEDS_TEST)
test_rewards = []

max_steps = 1000

for episode in range(test_episodes):
    state = env.reset(seed = SEEDS_TEST[episode])
    state = state[0] if isinstance(state, tuple) else state
    done = False
    total_reward = 0
    frames = []
    
    for t in range(max_steps):
        frame = env.render()
        if frame is not None:
            frames.append(frame)
        action = agent.perform_greedy_action(state, eps = 0.0)  # Fully greedy policy
        next_state, reward, done, truncated, _ = env.step(action)
        state = next_state
        total_reward += reward

        if done: break
    
    test_rewards.append(total_reward)
    print(f"Test Episode {episode+1}, Total Reward: {total_reward}")
    
    if frames:
        os.makedirs(f"{env_name}/test_gifs", exist_ok=True)
        imageio.mimsave(f"{env_name}/test_gifs/test_episode_{episode+1}.gif", frames, fps=30)

env.close()

sf.save_test_results(env_name, test_rewards)
# Out:
# Test Episode 1, Total Reward: -6370.798916699913
# Test Episode 2, Total Reward: -6330.59378073205
# Test Episode 3, Total Reward: -6275.040884536123
# Test Episode 4, Total Reward: -6173.175699602742
# Test Episode 5, Total Reward: -6491.294875398975
# Plot saved at aaaDuelingDQN_Pendulum-v1_exponential_eps_decay/stats/plots/test_results.png
